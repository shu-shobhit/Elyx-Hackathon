# %%
from IPython.display import Image, display
import json
from typing import Dict, Any
from orchestrator import build_graph
from state import ConversationalState

# %%
graph = build_graph()

# %%
Image(graph.get_graph().draw_mermaid_png())

# %%
print(graph.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	RouterInit(RouterInit)
# 	Collector(Collector)
# 	RubyNode(RubyNode)
# 	DrWarrenNode(DrWarrenNode)
# 	AdvikNode(AdvikNode)
# 	CarlaNode(CarlaNode)
# 	RachelNode(RachelNode)
# 	NeelNode(NeelNode)
# 	__end__([<p>__end__</p>]):::last
# 	AdvikNode -.-> CarlaNode;
# 	AdvikNode -.-> Collector;
# 	AdvikNode -.-> DrWarrenNode;
# 	AdvikNode -.-> NeelNode;
# 	AdvikNode -.-> RachelNode;
# 	AdvikNode -.-> RubyNode;
# 	CarlaNode -.-> AdvikNode;
# 	CarlaNode -.-> Collector;
# 	CarlaNode -.-> DrWarrenNode;
# 	CarlaNode -.-> NeelNode;
# 	CarlaNode -.-> RachelNode;
# 	CarlaNode -.-> RubyNode;
# 	DrWarrenNode -.-> AdvikNode;
# 	DrWarrenNode -.-> CarlaNode;
# 	DrWarrenNode -.-> Collector;
# 	DrWarrenNode -.-> NeelNode;
# 	DrWarrenNode -.-> RachelNode;
# 	DrWarrenNode -.-> RubyNode;
# 	NeelNode -.-> AdvikNode;
# 	NeelNode -.-> CarlaNode;
# 	NeelNode -.-> Collector;
# 	NeelNode -.-> DrWarrenNode;
# 	NeelNode -.-> RachelNode;
# 	NeelNode -.-> RubyNode;
# 	RachelNode -.-> AdvikNode;
# 	RachelNode -.-> CarlaNode;
# 	RachelNode -.-> Collector;
# 	RachelNode -.-> DrWarrenNode;
# 	RachelNode -.-> NeelNode;
# 	RachelNode -.-> RubyNode;
# 	RouterInit -.-> AdvikNode;
# 	RouterInit -.-> CarlaNode;
# 	RouterInit -.-> Collector;
# 	RouterInit -.-> DrWarrenNode;
# 	RouterInit -.-> NeelNode;
# 	RouterInit -.-> RachelNode;
# 	RouterInit -.-> RubyNode;
# 	RubyNode -.-> AdvikNode;
# 	RubyNode -.-> CarlaNode;
# 	RubyNode -.-> Collector;
# 	RubyNode -.-> DrWarrenNode;
# 	RubyNode -.-> NeelNode;
# 	RubyNode -.-> RachelNode;
# 	__start__ --> RouterInit;
# 	Collector --> __end__;
# 	AdvikNode -.-> AdvikNode;
# 	CarlaNode -.-> CarlaNode;
# 	DrWarrenNode -.-> DrWarrenNode;
# 	NeelNode -.-> NeelNode;
# 	RachelNode -.-> RachelNode;
# 	RubyNode -.-> RubyNode;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
