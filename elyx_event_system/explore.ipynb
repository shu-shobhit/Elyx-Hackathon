# %%
from IPython.display import Image, display
import json
from typing import Dict, Any
from orchestrator import build_graph
from state import ConversationalState

# %%
graph = build_graph()

# %%
Image(graph.get_graph().draw_mermaid_png())

# %%
initial_state: ConversationalState = {
        "message": "I've been feeling tired lately and my sleep has been poor. Can you help me figure out what's going on?",
        "chat_history": [],
        "member_state": {
            "name": "John Doe",
            "week_index": 1,
            "has_whoop": True,
            "has_cgm": False
        },
        "week_index": 1,
        "pending_agents": [],
        "current_agent": None,
        "member_decision": None,
        "agent_responses": []
    }

# %%
result = graph.invoke(initial_state, config={"recursion_limit": 100})
# Out:
# --- Running Node: init_member_node ---
#   -> Successfully parsed initial member state.
# --- Running Node: member_node ---
#   -> Member says: 'Hi Elyx team, I'm Alex Tan. I'm reaching out because I'm motivated to take proactive control of my health, particularly given my family history of heart disease. I've set some goals for myself, including reducing my risk of heart disease, enhancing cognitive function, and implementing regular health screenings. I'd love to work with you to create a personalized plan that fits my busy lifestyle and helps me achieve these goals. Looking forward to hearing from you! 😊' (Decision: CONTINUE_CONVERSATION)
# --- Running Node: decider_node ---
#   -> Decider chose: Ruby
#   -> Ruby says: 'Hi Alex! 😊 It's wonderful to hear that you're taking proactive steps towards your health. I'm more than happy to help you create a personalized plan that fits your lifestyle and goals. Before we get started, I'd like to bring in Dr. Warren to discuss your health goals and family history of heart disease. She'll be able to provide expert guidance on reducing your risk of heart disease and enhancing cognitive function.'
# --- Running Node: agent_response_collector ---
#   -> Processed Ruby's response
# --- Running Node: decider_node ---
#   -> Decider chose: DrWarren
#   -> DrWarren says: 'Hi Alex, I'm Dr. Warren. I've reviewed your health goals and family history of heart disease. To better understand your current health status, I recommend a comprehensive diagnostic plan, including a lipid profile, complete blood count, and blood glucose test. This will help us identify potential risk factors and create a personalized plan to reduce your risk of heart disease and enhance cognitive function.'
# --- Running Node: agent_response_collector ---
#   -> Processed DrWarren's response
# --- Running Node: decider_node ---
#   -> Decider chose: Member
# --- Running Node: member_node ---
#   -> Member says: 'Hi Dr. Warren, thanks for getting back to me! The diagnostic plan sounds like a great idea. I'll schedule the tests as soon as possible. Can you elaborate on how the results will help tailor my personalized plan? 🤔' (Decision: CONTINUE_CONVERSATION)
# --- Running Node: decider_node ---
#   -> Decider chose: DrWarren
#   -> DrWarren says: 'The diagnostic plan will provide valuable insights into your current health status, allowing us to identify potential risk factors and create a personalized plan tailored to your needs. The lipid profile will assess your cholesterol levels, the complete blood count will evaluate your overall health, and the blood glucose test will help us understand your blood sugar levels.'
# --- Running Node: agent_response_collector ---
#   -> Processed DrWarren's response
# --- Running Node: decider_node ---
#   -> Decider chose: DrWarren
#   -> DrWarren says: 'The diagnostic plan will provide valuable insights into your current health status, allowing us to identify potential risk factors and create a personalized plan tailored to your needs. The lipid profile will assess your cholesterol levels, the complete blood count will evaluate your overall health, and the blood glucose test will help us understand your blood sugar levels.'
# --- Running Node: agent_response_collector ---
#   -> Processed DrWarren's response
# --- Running Node: decider_node ---
#   -> Decider chose: DrWarren
#   -> DrWarren says: 'The diagnostic plan will provide valuable insights into your current health status, allowing us to identify potential risk factors and create a personalized plan tailored to your needs. The lipid profile will assess your cholesterol levels, the complete blood count will evaluate your overall health, and the blood glucose test will help us understand your blood sugar levels.'
# --- Running Node: agent_response_collector ---
#   -> Processed DrWarren's response
# --- Running Node: decider_node ---
